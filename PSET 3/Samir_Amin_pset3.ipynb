# %% [markdown]
# <a href="https://colab.research.google.com/github/aminsamir45/MIT-9.40-Neural-Computation/blob/main/PSET%203/Samir_Amin_pset3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **PSET 3**
# ## Due 03/17/2023
#
#
#
# ---
#
#
# # NAME: Samir Amin
#
# # Gmail: aminsam@mit.edu

# %% [markdown]
# **Link to your Colab:** https://drive.google.com/file/d/1CQrLEK3MIaulNJicTDWruJ3L4cviPlfw/view?usp=sharing
#
#
#
#
# ---
#
#
#
# ---

# %% [markdown]
# # Learning objectives and outcomes:
#
# This problem set investigates the role of synapses in two-compartment cell models. In particular, we will analyze how the location of an inhibitory synapse affects the computational properties of a cell in a circuit mediating an escape response. More fundamentally, we will analyze how these biophysical and computational changes mediate different behaviors and are thus fundamental for survival of the species.
#
# .
#
#
# The role of synapses and the computational properties of 2-compartment models are discussed in lectures 6 & 7. Furthermore, this PSET is based on the assigned reading for lecture 7 (Vu and Krasne, 1992).
#
# .
#
# .
#
#
# The expected learning outcomes for this PSET are:
#
#
#
#
# *   Analyze two-compartment cell models and write current balance equations using Krichhoff’s and Ohm’s law.
# *   Be acquainted with shunting inhibition.
# *   Use the current balance equations to understand and analyze the different behaviors that arise when inhibition is located on a dendrite or near the soma.
# *   Make plots to visualize relative and absolute suppression in 2-compartment cell models.
# *   Disentangle in which scenarios excitation can override inhibition.
# *   Be able to present your results as a cohesive and well-structured report.
#
#
# .

# %% [markdown]
# # Introduction: Synapses as Computational Devices
#
#
# ## Escape response in the crayfish: computational roles of somatic (proximal) and dendritic (distal) inhibition
#
# Vu and Krasne (1992) studied the role of inhibition at two locations relative to the soma: near the soma (proximal configuration) and out in the dendrite (distal configuration). The main point of their study is to understand how inhibition location affects the initiation of the LG escape response in the crayfish (Check https://www.jove.com/video/1297/recordings-of-neural-circuit-activation-in-freely-behaving-animals
#  for a video exhibiting the behavior (Heberholz, 2009)).
#
# .
#
# In their analysis they argue that proximal (called “recurrent” in Vu and Krasne) inhibition can mediate an absolute suppression of the escape behavior. In contrast, distal (called “tonic” in Vu and Krasne) inhibition mediates a relative suppression that can always be overridden by sufficient strong excitatory input. These mechanisms are important to distinguish different behavioral scenarios. For an animal, it is often necessary to suppress certain behaviors completely, while under other conditions the threshold for initiating a behavior should only be elevated but the behavior should not be completely suppressed.  Altogether, once an escape response is initiated no other escape reflex should be triggered. However, during feeding or exploratory behaviors the threshold for an escape response should be set accordingly. This gives the biological background for the observed absolute and relative suppression.
#
# .
#
# In the next exercise we follow the analysis by Vu and Krasne. We will work on proximal and distal inhibition configurations on a two-compartment cell model to understand how absolute and relative suppression arise in each of these scenarios.
#
# .
#
#
# An inhibitory synapse produces different effects on the target cell depending on the value of the synaptic reversal potential $(E_{syn})$. If the synaptic reversal potential is below the target cell resting potential, inhibition will be hyperpolarizing and therefore will have a subtractive effect.  In contrast, if the synaptic reversal potential is identical (or very close) to the membrane resting potential, inhibition will have a "shunting" effect. Shunting inhibition is termed "shunting" because the synaptic conductance short-circuits currents that are generated at adjacent excitatory synapses. If a shunting inhibitory synapse is activated, the input resistance is reduced locally and, following Ohm’s law, the amplitude of subsequent excitatory postsynaptic potentials (EPSPs) is reduced. In this case inhibition per se does not affect the membrane potential as much as in the hyperpolarizing case, however it makes it harder to excite the cell.
#
# .
#
#
# For simplicity, and to be consistent with lecture notes we will call the inhibition locations somatic (proximal in the paper) and dendritic (distal in the paper). It is important to notice that crayfish neurons have a ganglionic morphological organization and that action potentials are not initiated in the soma but rather in a dendrite near the soma. This is the origin of the proximal and distal nomenclature, to refer to dendritic locations near and far from the soma respectively.
#
# .
#
# **References:**
#
#
# 1.   Vu, E. T. and Krasne, F. B. (1992). Evidence for a Computational Distinction Between
# Proximal and Distal Neuronal Inhibition. Science 255(5052): 1710-2.
# 2.   Herberholz, J. (2009). Recordings of Neural Circuit Activation in Freely Behaving
# Animals, Journal of Visualized Experiments 29, e1297.

# %% [markdown]
# **NOTE:**
#
# Both problems of this assignment are very similar, and many of the questions require only analytical answers.

# %% [markdown]
# # Problem 1: Somatic Inhibition
#
# In the circuit below, we depict a two-compartment model where the inhibitory synapse is located in the somatic compartment (proximal configuration).
#
#
#   ![circuit1_pset3.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# Notice that $G^*$ is a longitudinal resistor linking/coupling the two compartments. Also, to simplify the analysis we have set the resting membrane potential at 0 mV.  As inhibition is of the shunting type we have set $E_i$ to 0 mV (no battery) and thus there is no need to include a battery for this synapse. $V_d$ and $V_s$ are labels to indicate the membrane potential at the dendritic and somatic compartments, respectively.

# %% [markdown]
# ## **Question 1.1**
#
#
# Using Kirchhoff’s and Ohm’s law, write two equations, each one expressing the sum of currents at the dendritic and somatic compartments, respectively.

# %% [markdown]
# ### Answer 1.1
#
# (this is not a coding question)
#
# Tip: To display mathematical expressions, use double dollar signs instead of a single one.
#
# Kirchhoff's law:
#
# $$ -I^{*} = I_{e} + I_{d} $$
#
# $$ I^{*} = I_{i} + I_{s} $$
#
# Ohm's Law:
# $$ V_s = I_i/G_i $$
# $$ V_s = I_s/G_s $$
# $$ V_d = I_d/G_d $$
# $$ V_d = I_e/G_e + E_e $$
# $$ V_d - V_s = I^*/G^* $$
#
# Thus:
#
# $$ I^* - I^* = 0 $$
# $$ I^* = I^* $$
# $$ I_e + I_d = I_i + I_s $$
#
# Plug in Ohm's Law:
#
# $$ V_dG_e - E_eG_e + V_dG_d =  V_sG_i +V_sG_s$$
#
# $$(\frac{I^*}{G^*}+V_s)(G_e + G_d) - E_eG_e = V_s(G_i +G_s)$$
#
# $$(\frac{I_i+I_s}{G^* }+V_s)(G_e + G_d) - E_eG_e = V_s(G_i +G_s)$$
#
# $$(\frac{V_sG_i +V_sG_s}{G^* }+V_s)(G_e + G_d) - E_eG_e = V_s(G_i +G_s)$$
#
# <br>
# (double-click on this cell to see the latex command)
#
# ---
#
#
#
#
# .

# %% [markdown]
# ## **Question 1.2**
#
#
# Combine the above two equations to get a single expression for the voltage at the somatic compartment that does not depend on the voltage at the dendritic compartment. ( i.e to eliminate $V_d$). You should reach the following expression:
#
#
#
# $$ V_s = \frac{G_e G^* E_e}{G^* G_d + G_s G_d + G_s G^* + G_e(G_* + G_i + G_s) + G_i(G_d + G^*)} $$
#
# Show your work.

# %% [markdown]
# ### Answer 1.2
# First current equation:
#
# $$ 0 = I_* + I_d + I_e $$
#
# $$ 0 = (V_d - V_s)G^* + (V_dG_d) + (V_d - E_e)G_e $$
#
# $$ 0 = V_dG^* - V_sG^* + V_dG_d + V_dG_e - E_eG_e $$
#
# $$  V_dG^*  + V_dG_d + V_dG_e = E_eG_e  + V_sG^* $$
#
# $$  V_d(G^*  + G_d + G_e) = E_eG_e  + V_sG^* $$
#
# $$  V_d = \frac{E_eG_e  + V_sG^*}{G^*  + G_d + G_e} $$
#
# Second current equation:
#
# $$ 0 = I_s + I_i - I^* $$
#
# $$ 0 = -(V_d - V_s)G^* + V_sG_s + V_sG_i $$
#
# $$ V_dG^* - V_sG^* =  V_sG_s + V_sG_i $$
#
# $$ V_dG^* =  V_sG_s + V_sG_i + V_sG^* $$
#
# $$ V_d  =  \frac{V_s(G_s + G_i + G^*)}{G^*} $$
#
# Combining the two and solving for $V_s$:
#
# $$ \frac{E_eG_e  + V_sG^*}{G^*  + G_d + G_e} = \frac{V_s(G_s + G_i + G^*)}{G^*} $$
#
# $$ E_eG_eG^*  + V_s(G^*)^2 = V_s(G_s + G_i + G^*)(G^*  + G_d + G_e) $$
#
# $$ E_eG_eG^*  = V_s(G_s + G_i + G^*)(G^*  + G_d + G_e) - V_s(G^*)^2 $$
#
# $$ E_eG_eG^*  = V_s((G_s + G_i + G^*)(G^*  + G_d + G_e) - (G^*)^2) $$
#
# $$ V_s  = \frac{E_eG_eG^*}{((G_s + G_i + G^*)(G^*  + G_d + G_e) - (G^*)^2)} $$
#
# Which Finally simplifies to:
#
# $$ V_s = \frac{G_e G^* E_e}{G^* G_d + G_s G_d + G_s G^* + G_e(G_* + G_i + G_s) + G_i(G_d + G^*)} $$

# %% [markdown]
# ## **Question 1.3**
#
# Next consider the following parameter values:
#
# $G_d = G_s $
#
# $G^* = \frac{1}{9} G_s$
#
# $G_s = 1$
#
# $\alpha = \frac{G_i}{G_d} = \{ 0, 0.2, 0.5, 1, 2, 5 \}$
#
# $E_e = 100 \, mV$
#
#
#
# where $\alpha$  controls the inhibitory strength. Simplify the above expression for $V_s$ using these parameter relations. **Leave your answer in terms of $\alpha$.**
#
# .

# %% [markdown]
# ### Answer 1.3
#
# $G_d = 1 $
#
# $G^* = \frac{1}{9}$
#
# $G_s = 1$
#
# $\alpha = G_i = \{ 0, 0.2, 0.5, 1, 2, 5 \}$
#
# $E_e = 100 \, mV$
#
#
# ---
#
# Start by plugging in all known values to the previous equation from 1.2:
#
# $$ V_s = \frac{\frac{1}{9}G_e *100mV}{\frac{1}{9} + 1 + \frac{1}{9} + G_e(\frac{1}{9} + \alpha + 1) + \alpha(1 + \frac{1}{9})} $$
#
# Which simplifies to:
#
# $$ V_s = \frac{G_e*100mV}{11 + 10G_e + 9G_e\alpha + 10\alpha } $$

# %% [markdown]
# ## **Question 1.4**
#
# Using the expression for $E_e$ and $V_s$ from question 1.3, **plot** the voltage at the soma as a function of $G_e$ for **each** level of inhibition, $\alpha$. Use a **logarithmic scale** on the x-axis and set its range between 0.01 and 1000. **Overlay** all the curves in a single panel. This should look similar to figure 1A in Vu and Krasne (1992).
#
# .
#
# As in the paper, consider that the threshold for initiating an escape response is $9\,  mV$.

# %% [markdown]
# ### Answer 1.4

# %% [markdown]
# Back to coding!
#
# Tip: numpy.logspace, semilogx()
#
#
#
# .

# %%
import numpy as np
import matplotlib.pyplot as plt

def Vs(Ge, alpha):
    return Ge * 100e-3 / (11 + 9*(alpha*Ge) + 10*Ge + 10*alpha)

alpha_values = [0, 0.2, 0.5, 1, 2, 5]
Ge_values = np.logspace(-2, 3, num=200)

fig, ax = plt.subplots()

for alpha in alpha_values:
    ax.plot(Ge_values, Vs(Ge_values, alpha), label=f"α = {alpha}")
    
ax.axhline(y=9e-3, color='black', linestyle='--')
ax.set_xlabel("G_e (nS)")
ax.set_ylabel("V_s (mV)")
ax.set_xscale('log')
ax.set_xlim([0.01, 1000])
ax.legend()

plt.show()

# %% [markdown]
# ## **Question 1.5**
#
# Note that in the previous plot, strong inhibition is always capable of suppressing the voltage at the soma. To show this, take the limit of $G_e$ going to infinity on the simplified equation for $V_s$. Write down the expression you got for this limit. In this limit, is Vs dependent or independent of inhibition?  Explain and relate to the plot in question 1.4. What type of suppression is this?

# %% [markdown]
# ### Answer 1.5
#
# Expression from 1.3:
#
# $$ V_s = \frac{G_e*100mV}{11 + 10G_e + 9G_e\alpha  + 10\alpha } $$
#
#
# Taking the limit of $G_e$ going to infinity on the simplified equation for $V_s$, we can write:
#
# $$ \lim_{G_e\rightarrow\infty} V_s = \frac{G_e*100mV}{11 + 10G_e + 9G_e\alpha + 10\alpha} $$
#
#
# $$ \lim_{G_e\rightarrow\infty} V_s =  \frac{100mV}{\frac{11}{G_e} + 10 + 9\alpha + \frac{10}{G_e}\alpha} $$
#
#
# $$ \lim_{G_e\rightarrow\infty} V_s = \frac{100mV}{10 + 9\alpha} $$
#
# In this limit, $V_s$ is dependent of inhibition, since it depends on the value of $\alpha$, the variable that controls the inhibtory strength, and approaches a value of $\frac{100mV}{1+9\alpha}$ as $G_e$ goes to infinity. This is classified as proximal inhibition (absolute inhibition).
#
# Relating to the plot in question 1.4, we can see that for both lower and higher values of $G_e$, the curves all converge to a horizontal line, indicating that the voltage at the soma is independent of inhibition in this limit. This type of suppression is called recurrent inhibition which occurrs when another escape behavior is in progress and another escape behavior is introduced.
#
# ---
#
#
#
# .

# %% [markdown]
# ---
#
#
#
# ---

# %% [markdown]
# ---
#
# ---

# %% [markdown]
# # **Problem 2: Dendritic Inhibition**
#
#
#
# In the circuit below we depict a two-compartment model where the inhibitory synapse is
# located in the dendritic compartment with the same considerations as in problem 1.
#
# .
#
#
# .  ![circuits2_pset3.jpg](data:image/jpeg;base64,...)
#
#
# ..
#
#
#
# .

# %% [markdown]
# ## **Question 2.1**
#
#
# Using Kirchoff’s and Ohm’s law, write two equations, each one expressing the
# sum of currents at the dendritic and somatic compartments, respectively.

# %% [markdown]
# ### Answer 2.1
# Kirchhoff's law:
#
# $$ -I^{*} = I_{e} + I_{d} + I_{i} $$
# $$ I^{*} =  I_{s} $$
#
#
# Ohm's Law:
# $$ V_s = I_s/G_s $$
# $$ V_d = I_i/G_i $$
# $$ V_d = I_d/G_d $$
# $$ V_d = I_e/G_e + E_e $$
# $$ V_d - V_s = I^*/G^* $$
#
# Thus:
# $$ I^* - I^* = 0 $$
# $$ I^* = I^* $$
# $$ I_e + I_d + I_i= I_s $$
#
# Plug in Ohm's Law:
#
# $$ V_dG_e - E_eG_e + V_dG_d + V_dG_i = V_sG_s$$
#
# $$(\frac{I^*}{G^*}+V_s)(G_e + G_d +G_i) - E_eG_e = V_sG_s$$
#
# $$(\frac{I_s}{G^*}+V_s)(G_e + G_d +G_i) - E_eG_e = V_sG_s$$
#
# $$(\frac{V_sG_s}{G^*}+V_s)(G_e + G_d +G_i) - E_eG_e = V_sG_s$$
#
#
#
#
# ---

# %% [markdown]
# ## **Question 2.2**
#
# Combine the above two equations to get a single expression for the voltage
# at the somatic compartment that does not depend on the voltage at the
# dendritic compartment. (i.e. to eliminate $V_d$). You should reach the following
# expression:
#
# .
#
# $$ V_s=\frac{G_eG^*E_e } { G^*G_d+G_dG_s+G^*G_s+G_e\left(G^*+G_s\right)+ G_i \left(G^*+G_s\right)}$$
#
#
# .
#
#
# Show your work.

# %% [markdown]
# ### Answer 2.2
#
#
# First current equation:
#
# $$ 0 = I_e + I_d + I_i + I^* $$
#
# $$ 0 = (V_d - V_s)G^* + V_dG_d + (V_d - E_e)G_e + V_dG_i$$
#
# $$ 0 = V_dG^* - V_sG^* + V_dG_d + V_dG_e - E_eG_e + V_dG_i $$
#
# $$  V_dG^*  + V_dG_d + V_dG_e + V_dG_i= E_eG_e  + V_sG^* $$
#
# $$  V_d(G^*  + G_d + G_e + G_i) = E_eG_e  + V_sG^* $$
#
# $$  V_d = \frac{E_eG_e  + V_sG^*}{G^*  + G_d + G_e + G_i} $$
#
# Second current equation:
#
# $$ 0 = I_s - I^* $$
#
# $$ 0 = -(V_d - V_s)G^* + V_sG_s $$
#
# $$ V_dG^* - V_sG^* =  V_sG_s $$
#
# $$ V_dG^* =  V_sG_s + V_sG^* $$
#
# $$ V_d  =  \frac{V_s(G_s + G^*)}{G^*} $$
#
# Combining the two and solving for $V_s$:
#
# $$ \frac{E_eG_e  + V_sG^*}{G^*  + G_d + G_e + G_i} = \frac{V_s(G_s + G^*)}{G^*} $$
#
# $$ E_eG_eG^*  + V_s(G^*)^2 = V_s(G_s  + G^*)(G^*  + G_d + G_e + G_i) $$
#
# $$ E_eG_eG^*  = V_s(G_s + G^*)(G^*  + G_d + G_e + G_i) - V_s(G^*)^2 $$
#
# $$ E_eG_eG^*  = V_s((G_s + G^*)(G^*  + G_d + G_e + G_i) - (G^*)^2) $$
#
# $$ V_s  = \frac{E_eG_eG^*}{((G_s + G^*)(G^*  + G_d + G_e + G_i) - (G^*)^2)} $$
#
# Which Finally simplifies to:
#
# $$ V_s=\frac{G_eG^*E_e } { G^*G_d+G_dG_s+G^*G_s+G_e\left(G^*+G_s\right)+ G_i \left(G^*+G_s\right)}$$
#
#
#
#
# .
#
#
#
#
# ---

# %% [markdown]
# ## **Question 2.3**
#
# Next consider the following parameter values:
#
#
#
# $G_s = G_d$
#
# $G^* = \frac{1}{9} G_s$
#
# $G_s = 1$
#
# $\alpha = \frac{G_i}{G_d} = \{ 0, 0.2, 0.5, 1, 2, 5 \}$
#
#
# $E_e = 100 \, mV$
#
#
# .
#
# where $\alpha$  controls the inhibitory strength. Simplify the above expression for $V_s$ using this parameter relations. Keep your answer as a function of $G_e$ and $\alpha$.

# %% [markdown]
# ### Answer 2.3
#
# $G_d = 1 $
#
# $G^* = \frac{1}{9}$
#
# $G_s = 1$
#
# $\alpha = G_i = \{ 0, 0.2, 0.5, 1, 2, 5 \}$
#
# $E_e = 100 mV$
#
#
# ---
#
# Start by plugging in all known values to the previous equation from 1.2:
#
# $$ V_s = \frac{\frac{1}{9}G_e *100mV}{\frac{1}{9} + 1 + \frac{1}{9} + G_e(\frac{1}{9} + 1) + \alpha(1 + \frac{1}{9})} $$
#
# Which simplifies to:
#
# $$ V_s = \frac{G_e*100mV}{11 + 10G_e  + 10\alpha} $$
#
# .
#
#
#
#
# ---

# %% [markdown]
# ## **Question 2.4**
#
#
# Using the expression from question 2.3, plot the voltage at the soma as a function of $G_e$ for each level of inhibition. Use a logarithmic scale on the x-axis and set its range between 0.01 and 1000.
#
# Overlay all the curves in a single panel. This should look similar to figure 1A in Vu and Krasne (1992) .

# %% [markdown]
# ### Answer 2.4

# %%
def Vs(Ge, alpha):
    return Ge * 100e-3 / (11 + 10*Ge + 10*alpha)

alpha_values = [0, 0.2, 0.5, 1, 2, 5]
Ge_values = np.logspace(-2, 3, num=200)

fig, ax = plt.subplots()

for alpha in alpha_values:
    ax.plot(Ge_values, Vs(Ge_values, alpha), label=f"α = {alpha}")
    
ax.axhline(y=9e-3, color='black', linestyle='--')
ax.set_xlabel("G_e (nS)")
ax.set_ylabel("V_s (mV)")
ax.set_xscale('log')
ax.set_xlim([0.01, 1000])
ax.legend()

plt.show()

# %% [markdown]
# ## **Question 2.5**
#
# Note that in the previous plot, strong excitation is always capable to overcome inhibition. To show this, take the limit of $G_e$ going to infinity on the simplified equation for Vs. Write down the expression you got for this limit. In this limit, is $V_s$ dependent or independent of inhibition?  Explain and relate to the plot in question 4. What type of suppression is this?

# %% [markdown]
# ### Answer 2.5
#
# Expression from 1.3:
#
# $$ V_s = \frac{G_e*100mV}{11 + 10G_e  + 10\alpha } $$
#
#
# Taking the limit of $G_e$ going to infinity on the simplified equation for $V_s$, we can write:
#
# $$ \lim_{G_e\rightarrow\infty} V_s = \frac{G_e*100mV}{11 + 10G_e + 10\alpha} $$
#
#
# $$ \lim_{G_e\rightarrow\infty} V_s = \frac{100mV}{\frac{11}{G_e} + 10 + \frac{10}{G_e}\alpha} $$
#
#
# $$ \lim_{G_e\rightarrow\infty} V_s = \frac{100mV}{10} = 10 mV$$
#
# As the limit of $G_e$ goes to infinity, the expression for $V_s$ simplifies to a constant value of 10mV, which is independent of inhibition. This means that no matter how strong the inhibitory input is $\alpha$, the excitatory input will always dominate and cause an output response of 10mV. This is classified as distal inhibition (relative inhibition).
#
# This is consistent with the plot in question 4, where we see that strong excitation is always capable of overcoming inhibition. The type of suppression observed in this case is tonic inhibition, inhibition that occurs when the subject (crayfish) are feeding or restrained such that the likelihood of escape is reduced.
#
#
#
# .
#
#
#
# ---
#
#
#
# ---
